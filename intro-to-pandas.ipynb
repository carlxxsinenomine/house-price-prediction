# %%
import pandas as pd

# %%
# Series Datatype
# Takes a list
# Series = 1-dimensional
series = pd.Series(["BMW", "Toyota", "Honda"])
colors = pd.Series(["Red", "Green", "Blue"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: str

# %%
# DataFrame = 2-dimensional
car_data = pd.DataFrame({"Car make": series, "Color": colors})
car_data
# Out:
#   Car make  Color
# 0      BMW    Red
# 1   Toyota  Green
# 2    Honda   Blue

# %%
# Import data
car_sales = pd.read_csv('data/car-sales.csv')

# %%
car_sales
# Row = Axis 0
# Column = Axis 1
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataframe
car_sales.to_csv("exported-car-sales.csv", index=False) # Set index to false para hindi masama sa pag export

# %% [markdown]
# ## Describing Data

# %%
car_sales.dtypes
# Out:
# Make               str
# Colour             str
# Odometer (KM)    int64
# Doors            int64
# Price              str
# dtype: object

# %%
car_sales.columns # Outputs a list
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='str')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe() # Statistical info of numerical columns
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     str
#  1   Colour         10 non-null     str
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 1500, 111250])
car_prices.mean()
# Out:
# np.float64(38583.333333333336)

# %%
car_sales.sum(numeric_only=True)
# Out:
# Odometer (KM)    786014
# Doors                40
# dtype: int64

# %% [markdown]
# ## Viewing and Selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc
animals = pd.Series(['cat', 'dog', 'bird', 'panda', 'snake'], index=[0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: str

# %%
animals.loc[3] # refers to the index numbers
# Out:
# 3      dog
# 3    snake
# dtype: str

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: str

# %%
# .iloc refers to the position (like a normal array)
animals.iloc[3]
# Out:
# 'panda'

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: str

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales[car_sales['Make'] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
# Compare two columns
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby
car_sales.groupby(['Make']).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales['Odometer (KM)'].plot()
# Out:
# <Axes: >

# %%
car_sales['Odometer (KM)'].hist()
# Out:
# <Axes: >

# %%
# Convert from string to int
car_sales['Price'] = (car_sales['Price'].astype(str).replace(r'[\$,]', '', regex=True).astype(float))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales['Price'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales['Make'] = car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv('data/car-sales-missing-data.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Fill NaN Vals
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(numeric_only=True))
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'] = car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(numeric_only=True))

# %%
car_sales_missing.head(len(car_sales_missing))
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
# Column from series
seats_col = pd.Series([5, 5, 5, 5, 5])

# Create a new column called seats
car_sales['Seats'] = seats_col
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales['Seats'].fillna(5, inplace=True)
# Out:
# C:\Users\Calexx\AppData\Local\Temp\ipykernel_35044\1438083764.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   car_sales['Seats'].fillna(5, inplace=True)
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# 5    5.0
# 6    5.0
# 7    5.0
# 8    5.0
# 9    5.0
# Name: Seats, dtype: float64

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
# Col from python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 8.6, 8.9,9.5, 6.9, 7.8]
car_sales['Fuel per 100KM'] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    NaN             8.6
# 6   honda   Blue          45698      4   7500.0    NaN             8.9
# 7   honda   Blue          54738      4   7000.0    NaN             9.5
# 8  toyota  White          60000      4   6250.0    NaN             6.9
# 9  nissan  White          31600      4   9700.0    NaN             7.8

# %%
car_sales['Total fuel used'] = car_sales['Odometer (KM)']/100 * car_sales['Fuel per 100KM']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    NaN             8.6
# 6   honda   Blue          45698      4   7500.0    NaN             8.9
# 7   honda   Blue          54738      4   7000.0    NaN             9.5
# 8  toyota  White          60000      4   6250.0    NaN             6.9
# 9  nissan  White          31600      4   9700.0    NaN             7.8
#
#    Total fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        18539.265
# 5         8532.318
# 6         4067.122
# 7         5200.110
# ...

# %%
# Create a column from a single value
car_sales['Number of wheels'] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    NaN             8.6
# 6   honda   Blue          45698      4   7500.0    NaN             8.9
# 7   honda   Blue          54738      4   7000.0    NaN             9.5
# 8  toyota  White          60000      4   6250.0    NaN             6.9
# 9  nissan  White          31600      4   9700.0    NaN             7.8
#
#    Total fuel used  Number of wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1627.450                 4
# ...

# %%
car_sales['Total fuel used (L)'] = car_sales['Odometer (KM)']/100 * car_sales['Fuel per 100KM']

# %%
car_sales = car_sales.drop('Total fuel used', axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    NaN             8.6
# 6   honda   Blue          45698      4   7500.0    NaN             8.9
# 7   honda   Blue          54738      4   7000.0    NaN             9.5
# 8  toyota  White          60000      4   6250.0    NaN             6.9
# 9  nissan  White          31600      4   9700.0    NaN             7.8
#
#    Number of wheels  Total fuel used (L)
# 0                 4            11253.225
# 1                 4             8086.708
# 2                 4             1627.450
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 9  nissan  White          31600      4   9700.0    NaN             7.8
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 8  toyota  White          60000      4   6250.0    NaN             6.9
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 7   honda   Blue          54738      4   7000.0    NaN             9.5
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 5  toyota  Green          99213      4   4500.0    NaN             8.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 6   honda   Blue          45698      4   7500.0    NaN             8.9
#
#    Number of wheels  Total fuel used (L)
# 9                 4             2464.800
# 1                 4             8086.708
# 8                 4             4140.000
# ...

# %%
# Only select 20% of data if working with large datasets ( Start with small dataset )
car_sales_shuffled.sample(frac=.2)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 9  nissan  White          31600      4   9700.0    NaN             7.8
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
#
#    Number of wheels  Total fuel used (L)
# 9                 4             2464.800
# 3                 4             1073.184

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 9  nissan  White          31600      4   9700.0    NaN             7.8
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 8  toyota  White          60000      4   6250.0    NaN             6.9
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 7   honda   Blue          54738      4   7000.0    NaN             9.5
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 5  toyota  Green          99213      4   4500.0    NaN             8.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 6   honda   Blue          45698      4   7500.0    NaN             8.9
#
#    Number of wheels  Total fuel used (L)
# 9                 4             2464.800
# 1                 4             8086.708
# 8                 4             4140.000
# ...

# %%
car_sales_shuffled.reset_index(inplace=True, drop=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  nissan  White          31600      4   9700.0    NaN             7.8
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota  White          60000      4   6250.0    NaN             6.9
# 3  toyota   Blue          32549      3   7000.0    5.0             5.0
# 4   honda   Blue          54738      4   7000.0    NaN             9.5
# 5     bmw  Black          11179      5  22000.0    5.0             9.6
# 6  toyota  Green          99213      4   4500.0    NaN             8.6
# 7  nissan  White         213095      4   3500.0    5.0             8.7
# 8  toyota  White         150043      4   4000.0    5.0             7.5
# 9   honda   Blue          45698      4   7500.0    NaN             8.9
#
#    Number of wheels  Total fuel used (L)
# 0                 4             2464.800
# 1                 4             8086.708
# 2                 4             4140.000
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    NaN             8.6
# 6   honda   Blue          45698      4   7500.0    NaN             8.9
# 7   honda   Blue          54738      4   7000.0    NaN             9.5
# 8  toyota  White          60000      4   6250.0    NaN             6.9
# 9  nissan  White          31600      4   9700.0    NaN             7.8
#
#    Number of wheels  Total fuel used (L)
# 0                 4            11253.225
# 1                 4             8086.708
# 2                 4             1627.450
# ...

# %%
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   4000.0    5.0             7.5
# 1   honda    Red      54936.875      4   5000.0    5.0             9.2
# 2  toyota   Blue      20343.125      3   7000.0    5.0             5.0
# 3     bmw  Black       6986.875      5  22000.0    5.0             9.6
# 4  nissan  White     133184.375      4   3500.0    5.0             8.7
# 5  toyota  Green      62008.125      4   4500.0    NaN             8.6
# 6   honda   Blue      28561.250      4   7500.0    NaN             8.9
# 7   honda   Blue      34211.250      4   7000.0    NaN             9.5
# 8  toyota  White      37500.000      4   6250.0    NaN             6.9
# 9  nissan  White      19750.000      4   9700.0    NaN             7.8
#
#    Number of wheels  Total fuel used (L)
# 0                 4            11253.225
# 1                 4             8086.708
# 2                 4             1627.450
# ...
